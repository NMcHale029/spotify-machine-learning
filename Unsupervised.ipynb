# %%
# Import required libraries
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import datasets
import matplotlib.pyplot as plt
import hvplot.pandas

# %%
# Read in the clean spotify data
file_path = Path("Resources/spotify_clean.csv")
df_spotify = pd.read_csv(file_path)

# Display sample data
df_spotify.head()
# Out:
#                                           track_name      track_artist  \
# 0  I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                    Memories - Dillon Francis Remix          Maroon 5
# 2                    All the Time - Don Diablo Remix      Zara Larsson
# 3                  Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4            Someone You Loved - Future Humans Remix     Lewis Capaldi
#
#   track_album_release_date  danceability    energy       key  loudness  mode  \
# 0               2019-06-14      0.642049  1.201614  0.173200  1.367123     1
# 1               2019-12-13      0.490412  0.643317  1.557627  0.585766     1
# 2               2019-07-05      0.138889  1.284529 -1.211227  1.100090     0
# 3               2019-07-19      0.435271  1.279002  0.450085  0.984309     1
# 4               2019-03-05     -0.033426  0.742815 -1.211227  0.685151     1
#
#    speechiness  acousticness  ...  playlist_subgenre_new jack swing  \
# ...

# %%
df_spotify = df_spotify.set_index(['track_name', 'track_artist'])
df_spotify.head()
# Out:
#                                                                     track_album_release_date  \
# track_name                                         track_artist
# I Don't Care (with Justin Bieber) - Loud Luxury... Ed Sheeran                     2019-06-14
# Memories - Dillon Francis Remix                    Maroon 5                       2019-12-13
# All the Time - Don Diablo Remix                    Zara Larsson                   2019-07-05
# Call You Mine - Keanu Silva Remix                  The Chainsmokers               2019-07-19
# Someone You Loved - Future Humans Remix            Lewis Capaldi                  2019-03-05
#
#                                                                      danceability  \
# track_name                                         track_artist
# I Don't Care (with Justin Bieber) - Loud Luxury... Ed Sheeran            0.642049
# Memories - Dillon Francis Remix                    Maroon 5              0.490412
# ...

# %%
# Set the X and y variables
X = df_spotify.drop(columns=['track_album_release_date', 'bangers'])
y = df_spotify['track_popularity']

# %%
# Visualize a scatter plot of the data
df_spotify.hvplot.scatter(x="track_popularity", y="energy")
# Out:
# :Scatter   [track_popularity]   (energy)

# %%
df_spotify.head()
# Out:
#                                                                     track_album_release_date  \
# track_name                                         track_artist
# I Don't Care (with Justin Bieber) - Loud Luxury... Ed Sheeran                     2019-06-14
# Memories - Dillon Francis Remix                    Maroon 5                       2019-12-13
# All the Time - Don Diablo Remix                    Zara Larsson                   2019-07-05
# Call You Mine - Keanu Silva Remix                  The Chainsmokers               2019-07-19
# Someone You Loved - Future Humans Remix            Lewis Capaldi                  2019-03-05
#
#                                                                      danceability  \
# track_name                                         track_artist
# I Don't Care (with Justin Bieber) - Loud Luxury... Ed Sheeran            0.642049
# Memories - Dillon Francis Remix                    Maroon 5              0.490412
# ...

# %%
new_df = df_spotify.drop(columns=['track_album_release_date'])

# Start by importing the K-means algorithm
from sklearn.cluster import KMeans

# Create and initialize the K-means model instance for 2 clusters
model = KMeans(n_clusters=3, random_state=1)

# Print the model
model.fit(new_df)

song_clusters = model.predict(new_df)

song_clusters
# Out:
# c:\Users\kxand\.conda\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([1, 1, 1, ..., 1, 0, 0])

# %%
new_df['k_clusters'] = song_clusters
new_df.head()
# Out:
#                                                                      danceability  \
# track_name                                         track_artist
# I Don't Care (with Justin Bieber) - Loud Luxury... Ed Sheeran            0.642049
# Memories - Dillon Francis Remix                    Maroon 5              0.490412
# All the Time - Don Diablo Remix                    Zara Larsson          0.138889
# Call You Mine - Keanu Silva Remix                  The Chainsmokers      0.435271
# Someone You Loved - Future Humans Remix            Lewis Capaldi        -0.033426
#
#                                                                        energy  \
# track_name                                         track_artist
# I Don't Care (with Justin Bieber) - Loud Luxury... Ed Sheeran        1.201614
# Memories - Dillon Francis Remix                    Maroon 5          0.643317
# All the Time - Don Diablo Remix                    Zara Larsson      1.284529
# ...

# %%
## Plot and Analyze the Results
# Group the saved DataFrame by cluster using `groupby` to calculate average currency returns
new_df.groupby(by=['k_clusters'])['track_popularity'].mean()
# Out:
# k_clusters
# 0    33.241873
# 1    45.275855
# 2    41.560833
# Name: track_popularity, dtype: float64

# %%
new_df.hvplot.scatter(
    x="track_popularity",
    y="speechiness",
    by="k_clusters"
)
# Out:
# :NdOverlay   [k_clusters]
#    :Scatter   [track_popularity]   (speechiness)

# %%
new_df.hvplot.scatter(
    x="speechiness",
    y="instrumentalness",
    by="k_clusters"
)
# Out:
# :NdOverlay   [k_clusters]
#    :Scatter   [speechiness]   (instrumentalness)

# %%
new_df.hvplot.scatter(
    x="track_popularity",
    y="instrumentalness",
    by="k_clusters"
)
# Out:
# :NdOverlay   [k_clusters]
#    :Scatter   [track_popularity]   (instrumentalness)

# %%
# Create a a list to store inertia values
inertia = []

# Create a a list to store the values of k
k = list(range(1, 11))

# %%
# Create a for-loop where each value of k is evaluated using the K-means algorithm
# Fit the model using the spread_df DataFrame
# Append the value of the computed inertia from the `inertia_` attribute of the KMeans model instance
for i in k:
    k_model = KMeans(n_clusters=i, random_state=1)
    k_model.fit(X)
    inertia.append(k_model.inertia_)
# Out:
# c:\Users\kxand\.conda\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\kxand\.conda\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\kxand\.conda\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\kxand\.conda\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# Create a Dictionary that holds the list values for k and inertia
elbow_data = {"k": k, "inertia": inertia}

# Create a DataFrame using the elbow_data Dictionary
df_elbow = pd.DataFrame(elbow_data)

# Review the DataFrame
df_elbow.head()
# Out:
#    k       inertia
# 0  1  1.175422e+14
# 1  2  4.794991e+13
# 2  3  2.643769e+13
# 3  4  1.622646e+13
# 4  5  1.110856e+13

# %%
# Plot the DataFrame
df_elbow.hvplot.line(
    x="k", 
    y="inertia", 
    title="Elbow Curve", 
    xticks=k
)
# Out:
# :Curve   [k]   (inertia)

# %%
# Define the model with the lower value of k clusters
# Use a random_state of 1 to generate the model
model = KMeans(n_clusters=3, random_state=1)

# Fit the model
model.fit(X)

# Make predictions
k_lower = model.predict(X)

# Create a copy of the DataFrame and name it as spread_df_predictions
spread_df_predictions = X.copy()

# Add a class column with the labels to the spread_df_predictions
spread_df_predictions = X.copy()

# Add a class column with the labels to the spread_df_pr
# Out:
# c:\Users\kxand\.conda\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Define the model with the higher value of k clusters
# Use a random_state of 1 to generate the model
model = KMeans(n_clusters=4, random_state=1)

# Fit the model
model.fit(X)

# Make predictions
k_higher = model.predict(X)

# Add a class column with the labels to the spread_df_predictions DataFrame
spread_df_predictions['clusters_higher'] = k_higher
# Out:
# c:\Users\kxand\.conda\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
